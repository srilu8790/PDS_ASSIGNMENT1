# %%
import pandas as pd

# %%
data_frame = pd.read_csv('frailty_clean.csv')
print(data_frame.to_string())
# Out:
#    Unnamed: 0.1  Unnamed: 0  Height  Weight  Age  Grip Strength Frailty
# 0             0           0    65.8     112   30             30       N
# 1             1           1    71.5     136   19             31       N
# 2             2           2    69.4     153   45             29       N
# 3             3           3    68.2     142   22             28       Y
# 4             4           4    67.8     144   29             24       Y
# 5             5           5    68.7     123   50             26       N
# 6             6           6    69.8     141   51             22       Y
# 7             7           7    70.1     136   23             20       Y
# 8             8           8    67.9     112   17             19       N
# 9             9           9    66.8     120   39             31       N

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0.1   10 non-null     int64
#  1   Unnamed: 0     10 non-null     int64
#  2   Height         10 non-null     float64
#  3   Weight         10 non-null     int64
#  4   Age            10 non-null     int64
#  5   Grip Strength  10 non-null     int64
#  6   Frailty        10 non-null     object
# dtypes: float64(1), int64(5), object(1)
# memory usage: 688.0+ bytes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
axis_ = data_frame.plot.scatter(x='Weight',y='Grip Strength',color='pink')
fig_ = axis_.get_figure()
fig_.savefig("Relation.png")

# %%
plt.hist(data_frame['Grip Strength'],bins=35,edgecolor='k',color='pink')
plt.savefig("relation1.png")
plt.xlabel('Grip Strength')
plt.show()
